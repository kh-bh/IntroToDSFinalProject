# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
YTSHighdf = pd.read_csv("../YTS Data\YTSCessationData.csv")
YTSMiddledf = pd.read_csv("../YTS Data\YTSMiddleData.csv")
YTSSmokelessTobaccodf = pd.read_csv("../YTS Data\YTSSmokelessTobaccoData.csv")
YTSCigaretteUsedf = pd.read_csv("../YTS Data\YTSCigaretteUseData.csv")
YTSCessationdf = pd.read_csv("../YTS Data\YTSCessationData.csv")

# %%
#creating graph for Cessation Data
years = YTSCigaretteUsedf['Year'].unique()
datavalue = YTSCessationdf.groupby(['MeasureDesc','Year']).agg({'DataValue': ['mean']})

stderror = YTSCessationdf.groupby(['MeasureDesc','Year']).agg({'DataValueStdErr': ['mean']})
meansstd = stderror['DataValueStdErr']
print (meansstd)
plt.figure(figsize=(10, 6))
plt.scatter(years,datavalue[0:19],label='label1')
plt.scatter(years,datavalue[19:],label='label1')
plt.xticks(years)
plt.xticks(rotation=45)
plt.tight_layout()

plt.legend(["Percent of Current Smokers Who Want to Quit" , "Quit Attempt in Past Year Among Current Cigarette Smokers"])

plt.xlabel('Year')
plt.ylabel('Percent')

#plt.errorbar(years, datavalue[0:19], yerr=meansstd[0:19], fmt="o")
# Out:
#                                                              mean
# MeasureDesc                                        Year
# Percent of Current Smokers Who Want to Quit        1999  4.227778
#                                                    2000  4.248201
#                                                    2001  4.491111
#                                                    2002  4.192920
#                                                    2003  4.712500
#                                                    2004  4.650877
#                                                    2005  5.557627
#                                                    2006  5.161818
#                                                    2007  5.146154
#                                                    2008  4.787500
#                                                    2009  5.137313
#                                                    2010  4.845652
#                                                    2011  5.312766
#                                                    2012  4.550000
#                                                    2013  5.477778
#                                                    2014  5.161538
#                                                    2015  5.125000
#                                                    2016  6.350000
#                                                    2017  6.666667
# Quit Attempt in Past Year Among Current Cigaret... 1999  3.900000
#                                                    2000  4.151724
#                                                    2001  3.990196
#                                                    2002  3.886364
#                                                    2003  5.001961
#                                                    2004  4.344643
#                                                    2005  5.162857
#                                                    2006  4.882000
#                                                    2007  5.157500
#                                                    2008  4.626087
#                                                    2009  5.012766
#                                                    2010  4.510526
#                                                    2011  4.963889
#                                                    2012  4.818182
#                                                    2013  5.045455
#                                                    2014  4.508696
#                                                    2015  5.426190
#                                                    2016  5.523077
#                                                    2017  6.614815
# Text(91.97222222222221, 0.5, 'Percent')

# %%
years = YTSCigaretteUsedf['Year'].unique()
datavalue = YTSCessationdf.groupby(['MeasureDesc','Education','Year']).agg({'DataValue': ['mean']})

#stderror = YTSCessationdf.groupby(['MeasureDesc','Education','Year']).agg({'DataValueStdErr': ['mean']})
print (datavalue[19:])
plt.figure(figsize=(10, 6))
plt.scatter(years,datavalue[0:19],label='percentquitmiddle')
plt.scatter(years,datavalue[19:38],label='percentquitmiddleh')
plt.scatter(years,datavalue[38:57],label='quitattemptmiddle')
plt.scatter(years,datavalue[57:],label='quitattempthigh')
plt.xticks(years)
plt.xticks(rotation=45)
plt.tight_layout()

plt.legend(["Percent of Current Smokers Who Want to Quit - Middle" , "Percent of Current Smokers Who Want to Quit - High", "Quit Attempt in Past Year Among Current Cigarette Smokers - Middle","Quit Attempt in Past Year Among Current Cigarette Smokers - High"])

plt.xlabel('Year')
plt.ylabel('Percent')
# Out:
#                                                                        DataValue
#                                                                             mean
# MeasureDesc                                        Education     Year
# Percent of Current Smokers Who Want to Quit        Middle School 1999  53.175000
#                                                                  2000  53.957746
#                                                                  2001  52.770370
#                                                                  2002  54.082143
#                                                                  2003  50.324138
#                                                                  2004  49.755556
#                                                                  2005  50.569565
#                                                                  2006  49.595455
#                                                                  2007  50.821053
#                                                                  2008  48.544444
#                                                                  2009  49.328000
#                                                                  2010  47.031250
#                                                                  2011  42.250000
#                                                                  2012  47.325000
#                                                                  2013  42.535294
#                                                                  2014  45.275000
#                                                                  2015  43.820000
#                                                                  2016  49.300000
#                                                                  2017  58.200000
# Quit Attempt in Past Year Among Current Cigaret... High School   1999  52.420000
#                                                                  2000  60.769565
#                                                                  2001  56.333333
#                                                                  2002  57.447273
#                                                                  2003  53.316667
#                                                                  2004  53.910714
#                                                                  2005  53.510256
#                                                                  2006  53.582143
#                                                                  2007  51.657143
#                                                                  2008  51.683333
#                                                                  2009  47.272000
#                                                                  2010  52.941667
#                                                                  2011  51.618182
#                                                                  2012  57.942857
#                                                                  2013  60.770270
#                                                                  2014  61.773684
#                                                                  2015  61.097143
#                                                                  2016  59.500000
#                                                                  2017  61.470833
#                                                    Middle School 1999  54.959259
#                                                                  2000  56.201316
#                                                                  2001  56.000000
#                                                                  2002  57.336364
#                                                                  2003  51.925926
#                                                                  2004  52.925000
#                                                                  2005  50.809677
#                                                                  2006  52.059091
#                                                                  2007  55.094737
#                                                                  2008  58.445455
#                                                                  2009  53.450000
#                                                                  2010  50.371429
#                                                                  2011  48.714286
#                                                                  2012  67.125000
#                                                                  2013  66.755556
#                                                                  2014  71.775000
#                                                                  2015  74.328571
#                                                                  2016  74.133333
#                                                                  2017  60.666667
# Text(91.97222222222221, 0.5, 'Percent')
