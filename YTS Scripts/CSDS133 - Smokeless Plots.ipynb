# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
YTSHighdf = pd.read_csv("../YTS Data\YTSCessationData.csv")
YTSMiddledf = pd.read_csv("../YTS Data\YTSMiddleData.csv")
YTSSmokelessTobaccodf = pd.read_csv("../YTS Data\YTSSmokelessTobaccoData.csv")
YTSCigaretteUsedf = pd.read_csv("../YTS Data\YTSCigaretteUseData.csv")
YTSCessationdf = pd.read_csv("../YTS Data\YTSCessationData.csv")

# %%
#creating graph for Cessation Data
years = YTSCigaretteUsedf['Year'].unique()
datavalue = YTSSmokelessTobaccodf.groupby(['Gender','Year']).agg({'DataValue': ['mean']})



plt.figure(figsize=(10, 6))
plt.plot(years,datavalue[0:19],label='male', marker = "^")
plt.plot(years,datavalue[19:38],label='female', marker = "o")
plt.plot(years,datavalue[38:57],label='all', marker = "s")
plt.xticks(years)
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)

plt.legend(["Male" , "Female", "Overall"])

plt.xlabel('Year')
plt.ylabel('Percent')
# Out:
# Text(91.97222222222221, 0.5, 'Percent')

# %%
#creating graph for Cessation Data
years = YTSSmokelessTobaccodf['Year'].unique()
datavalue = YTSSmokelessTobaccodf.groupby(['Response','Year']).agg({'DataValue': ['mean']})

plt.figure(figsize=(10, 6))
plt.plot(years,datavalue[0:19],label='label1', c = "seagreen", marker = "o")
plt.plot(years,datavalue[19:38],label='label1', c = "orange", marker = "o")
plt.plot(years,datavalue[38:],label='label1', c = "purple", marker = "o")
plt.xticks(years)
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(True)

plt.legend(["Current" , "Ever","Frequent"])

plt.xlabel('Year')
plt.ylabel('Mean Percent of Response')
# Out:
# Text(78.72222222222221, 0.5, 'Mean Percent of Response')
